# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 500)
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('https://raw.githubusercontent.com/21Ovi/DataScience-DataSets/main/insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.isnull().count()
# Out:
# age         1338
# sex         1338
# bmi         1338
# children    1338
# smoker      1338
# region      1338
# charges     1338
# dtype: int64

# %%
sns.lineplot(x='charges',y='smoker',data=df,hue='age')
plt.show()

# %%
sns.lineplot(x='smoker',y='charges',data=df,hue='age')
plt.show()

# %%
sns.lineplot(x='age',y='charges',data=df,hue='smoker')
plt.show()

# %%
sns.lineplot(x='region',y='charges',data=df,hue='smoker')
plt.show()

# %%
sns.scatterplot(x='age',y='charges',data=df,hue='smoker')
plt.show()

# %%
# sns.histplot(x='age',y='sex', data=df,hue='charges',kde=True)
# plt.show()

# %%
df.hist(column='age', grid=False, edgecolor='red')
plt.show()

# %%
sns.kdeplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
df.age.value_counts()
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
df.hist(column='bmi', grid=False, edgecolor='red')
plt.show()

# %%
sns.kdeplot(df['bmi'])
plt.show()

# %%
df.hist(column='charges', grid=False, edgecolor='red')
plt.show()

# %%
sns.kdeplot(df['charges'])
plt.show()

# %%
df.hist(column='children', grid=False, edgecolor='red')
plt.show()

# %%
sns.kdeplot(df['children'])
plt.show()

# %%
sns.displot(df.age)
plt.show()

# %%
sns.displot(df.charges)
plt.show()

# %%
sns.displot(df.bmi)
plt.show()

# %%
sns.catplot(x='age',data=df)

# %%
sns.countplot(x='bmi',data=df)
plt.show()

# %%
sns.pairplot(df, vars= ['age','bmi','children','charges'], hue='sex')
plt.show()

# %% [markdown]
# # Bivrariate Analysis

# %%
sns.relplot(x='age',y='charges',data=df,palette='huls')
plt.title("Effect of age on charge")

'''as age increases charge increases'''
# Out:
# 'as age increases charge increases'

# %%
sns.relplot(x='age', y='charges', hue= 'sex', data=df, palette='husl')
plt.title('Effect of Age on Charges')

'''
from 0-1000 no gender baised is there 
but after 1000, there is more densitiy of men in terms of taking insurace
'''
# Out:
# '\nfrom 0-1000 no gender baised is there \nbut after 1000, there is more densitiy of men in terms of taking insurace\n'

# %%
sns.relplot(x='age', y='charges', col='sex',data=df, palette='husl')
plt.show()

# %%
sns.relplot(x='age', y='charges', col='smoker',data=df, palette='husl')
plt.show()

# %%
sns.relplot(x='age', y='charges', col='region',data=df, palette='husl')
plt.show()

# %%
sns.relplot(x='age', y='charges', col='children',data=df, palette='husl')
plt.show()

# %% [markdown]
# * when children are 0 there are more number of insurance
# * as children getting increase number of premium decrease

# %%
sns.relplot(x='bmi',y='charges',col='children',data=df)

# %% [markdown]
# * when charge is from 0-10000 there are most number of premium
# * as number of children increases number of premium holder decreases
# * number of children are inversly proportional to number of client

# %%
sns.relplot(x='bmi',y='charges',col='smoker',data=df)

# %% [markdown]
# * Smokers are paying more than non-smokers
# * smoker's insurace charge starts from 13k, whereas non-smoker's insurance charge starts from 0-10000
# * there are more non-smokers than smokers

# %%
sns.relplot(x='bmi',y='charges',col='region',data=df)

# %% [markdown]
# * basically at the center of a graph people tend to be more fit

# %%
sns.relplot(x='children',y='charges',col='smoker',data=df)

# %% [markdown]
#    * when charge is from 0-10000 there are most number of premium
#    * as number of children increases number of premium holder decreases
#    * number of children are inversly proportional to number of client

# %%
sns.relplot(x='bmi',y='charges',col='smoker',style='sex',data=df)

# %% [markdown]
# * smoking women pay more charges than male

# %%
sns.catplot(x='children',y='charges',hue='smoker',kind='box',data=df, palette='Paired')

# %% [markdown]
# # Data Preprocessing

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
box=df[['age','bmi']]
plt.figure(figsize=(5,10),facecolor='white')
plotnumber=1

for column in box:
    if plotnumber <=3:
        ax = plt.subplot(3,1,plotnumber)
        sns.boxplot(x=box[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1

# %% [markdown]
# # Categorical Data Handling
# * The algorithm can only understand numbers hence conversion of categorical data is important
# * Methods to handle categorical data
#  <br> 1 using loc function and domain analysis
#  <br> 2 One hot encoding
#
#  <br> sudo code for loc function:
#  <br> df.loc[df[column] == '',column] = 'some numerical value'
#  <br> Why particular value taken reason should be reasonable

# %%
df.loc[df['sex']=='male','sex'] = 0

# %%
df.loc[df['sex']=='female','sex'] = 1

# %%
df
# Out:
#       age sex     bmi  children smoker     region      charges
# 0      19   1  27.900         0    yes  southwest  16884.92400
# 1      18   0  33.770         1     no  southeast   1725.55230
# 2      28   0  33.000         3     no  southeast   4449.46200
# 3      33   0  22.705         0     no  northwest  21984.47061
# 4      32   0  28.880         0     no  northwest   3866.85520
# ...   ...  ..     ...       ...    ...        ...          ...
# 1333   50   0  30.970         3     no  northwest  10600.54830
# 1334   18   1  31.920         0     no  northeast   2205.98080
# 1335   18   1  36.850         0     no  southeast   1629.83350
# 1336   21   1  25.800         0     no  southwest   2007.94500
# 1337   61   1  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.smoker.value_counts()
df.loc[df['smoker']=='yes','smoker'] = 1
df.loc[df['smoker']=='no','smoker'] = 0

# %%
df.region.value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
df.loc[df['region']=='southeast','region'] = 3
df.loc[df['region']=='southwest','region'] = 2
df.loc[df['region']=='northwest','region'] = 1
df.loc[df['region']=='northeast','region'] = 0

# %%
df
# Out:
#       age     bmi  children region      charges  smoker_yes  sex_male
# 0      19  27.900         0      2  16884.92400           1         0
# 1      18  33.770         1      3   1725.55230           0         1
# 2      28  33.000         3      3   4449.46200           0         1
# 3      33  22.705         0      1  21984.47061           0         1
# 4      32  28.880         0      1   3866.85520           0         1
# ...   ...     ...       ...    ...          ...         ...       ...
# 1333   50  30.970         3      1  10600.54830           0         1
# 1334   18  31.920         0      0   2205.98080           0         0
# 1335   18  36.850         0      3   1629.83350           0         0
# 1336   21  25.800         0      2   2007.94500           0         0
# 1337   61  29.070         0      1  29141.36030           1         0
#
# [1338 rows x 7 columns]

# %% [markdown]
# # One Hot Encoding

# %%
df.smoker.value_counts()
# Out:
# 0    1064
# 1     274
# Name: smoker, dtype: int64

# %%
df2 = pd.get_dummies(df['smoker'],prefix='smoker',drop_first=True)
df = pd.concat([df,df2],axis=1).drop(['smoker'],axis=1)

# %%
df2
# Out:
#       smoker_yes
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 1333           0
# 1334           0
# 1335           0
# 1336           0
# 1337           1
#
# [1338 rows x 1 columns]

# %%
df
# Out:
#       age     sex     bmi  children region      charges  smoker_yes
# 0      19  female  27.900         0      2  16884.92400           1
# 1      18    male  33.770         1      3   1725.55230           0
# 2      28    male  33.000         3      3   4449.46200           0
# 3      33    male  22.705         0      1  21984.47061           0
# 4      32    male  28.880         0      1   3866.85520           0
# ...   ...     ...     ...       ...    ...          ...         ...
# 1333   50    male  30.970         3      1  10600.54830           0
# 1334   18  female  31.920         0      0   2205.98080           0
# 1335   18  female  36.850         0      3   1629.83350           0
# 1336   21  female  25.800         0      2   2007.94500           0
# 1337   61  female  29.070         0      1  29141.36030           1
#
# [1338 rows x 7 columns]

# %%
df3 = pd.get_dummies(df['sex'],prefix='sex',drop_first=True)
df = pd.concat([df,df3],axis=1).drop(['sex'],axis=1)

# %%
df3
# Out:
#       sex_male
# 0            0
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 1333         1
# 1334         0
# 1335         0
# 1336         0
# 1337         0
#
# [1338 rows x 1 columns]

# %%
df
# Out:
#       age     bmi  children region      charges  smoker_yes  sex_male
# 0      19  27.900         0      2  16884.92400           1         0
# 1      18  33.770         1      3   1725.55230           0         1
# 2      28  33.000         3      3   4449.46200           0         1
# 3      33  22.705         0      1  21984.47061           0         1
# 4      32  28.880         0      1   3866.85520           0         1
# ...   ...     ...       ...    ...          ...         ...       ...
# 1333   50  30.970         3      1  10600.54830           0         1
# 1334   18  31.920         0      0   2205.98080           0         0
# 1335   18  36.850         0      3   1629.83350           0         0
# 1336   21  25.800         0      2   2007.94500           0         0
# 1337   61  29.070         0      1  29141.36030           1         0
#
# [1338 rows x 7 columns]

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ### Remove unique columns, constant columns, name, email,phone number

# %%
df_corr = df[['age','bmi','children']]

plt.figure(figsize=(10,10))
sns.heatmap(df_corr.corr(),annot=True,cmap='turbo')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Linear Regression

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
## defining independent and dependent variable
x = df.drop(['charges'],axis=1)
y = df['charges']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#       age     bmi  children region  smoker_yes  sex_male
# 560    46  19.950         2      1           0         0
# 1285   47  24.320         0      0           0         0
# 1142   52  24.860         0      3           0         0
# 969    39  34.320         5      3           0         0
# 486    54  21.470         3      1           0         0
# ...   ...     ...       ...    ...         ...       ...
# 1095   18  31.350         4      0           0         0
# 1130   39  23.870         5      3           0         0
# 1294   58  25.175         0      0           0         1
# 860    37  47.600         2      2           1         0
# 1126   55  29.900         0      2           0         1
#
# [1070 rows x 6 columns]
#       age     bmi  children region  smoker_yes  sex_male
# 764    45  25.175         2      0           0         0
# 887    36  30.020         0      1           0         0
# 890    64  26.885         0      1           1         0
# ...

# %%
Lin_reg = LinearRegression()
Lin_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(Lin_reg.intercept_)
print(Lin_reg.coef_)
# Out:
# -12076.687687021013
# [ 2.56600616e+02  3.39184210e+02  4.23674513e+02 -2.41362103e+02
#   2.36702619e+04 -1.85353207e+01]

# %%
## Model Evaluation
## prediction on training data 

y_train_predict = Lin_reg.predict(x_train)

from sklearn.metrics
